# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = np.loadtxt('22221b.txt')
print(data)

def lorentzian(x, x0, a, gam)
    return a * gam**2 / (gam**2 + (x - x0)**2)

def multi_lorentzian(x, params)
    off = params[0]
    paramsRest = param[1:]
    assert not (len(paramsRest) % 3)
    return off + sum([lorentzian(x,*paramsRest[i:i+3]) for i in range(0, len(paramsRest),3)])
def res_multi_lorentz(params, xData, yData):
    diff = [multi_lorentzian(x, params) - y for x, y in zip(xData, yData)]
    return diff

xData, yData = np.loadtxt('22221b.txt', unpack=True )
yData = yData / max(yData)
# Out:
# [[  0.   1.   2. ... 509. 510. 511.]
#  [389. 376. 374. ... 361. 426. 390.]]

# %%
plt.scatter(data[0],data[1], s=1)
plt.xlim(0,511)
plt.ylim(150,550)
plt.title("Enriched Iron Mossbauer Effect", fontsize=12)
plt.xlabel('Channel', fontsize=8)
plt.ylabel('Counts',fontsize=8)
plt.show()
